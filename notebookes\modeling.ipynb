# %% [markdown]
# # Intelligent Loan Approval Prediction System ML Models
#
# The system is designed to predict the likelihood of loan approval by analyzing historical data containing applicants’ financial and personal attributes. By employing advanced ML algorithms, the model can capture complex patterns and relationships between features, enabling more informed and objective predictions.
#
# In this project, multiple machine learning models are explored and compared to identify the most effective approach for predicting loan approvals. The selected models include:
#
# - Logistic Regression
# - Random Forest
# - XGBoost
# - LightGBM
# - Support Vector Machine (SVM)
# - Neural Network
#
# By training and evaluating these models on historical loan datasets, the system aims to provide a reliable, data-driven mechanism for loan approval prediction. This approach not only helps financial institutions minimize default risk but also ensures a fair and consistent evaluation process for applicants.

# %% [markdown]
# # Install Dependencies

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.6.1)
# Requirement already satisfied: lightgbm>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (4.6.0)
# Requirement already satisfied: xgboost>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.0.4)
# Requirement already satisfied: tensorflow>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (2.19.0)
# Collecting scikeras>=0.6.0 (from -r requirements.txt (line 20))
#   Using cached scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting optuna>=3.0.0 (from -r requirements.txt (line 23))
#   Using cached optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting scikit-optimize>=0.9.0 (from -r requirements.txt (line 24))
#   Using cached scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: shap>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (0.48.0)
# Collecting fairlearn>=0.8.0 (from -r requirements.txt (line 30))
#   Using cached fairlearn-0.12.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 10)) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost>=1.7.0->-r requirements.txt (line 14)) (2.27.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.0->-r requirements.txt (line 23)) (1.16.5)
# Collecting colorlog (from optuna>=3.0.0->-r requirements.txt (line 23))
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.0->-r requirements.txt (line 23)) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.0->-r requirements.txt (line 23)) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.0->-r requirements.txt (line 23)) (6.0.2)
# Collecting pyaml>=16.9 (from scikit-optimize>=0.9.0->-r requirements.txt (line 24))
#   Using cached pyaml-25.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.0->-r requirements.txt (line 27)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.0->-r requirements.txt (line 27)) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.0->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0.0->-r requirements.txt (line 23)) (1.3.10)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.17.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.42.0->-r requirements.txt (line 27)) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0.0->-r requirements.txt (line 23)) (3.2.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.12.0->-r requirements.txt (line 17)) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 28.6 MB/s eta 0:00:00
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 12.5 MB/s eta 0:00:00
# Downloading fairlearn-0.12.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 25.1 MB/s eta 0:00:00
# Downloading pyaml-25.7.0-py3-none-any.whl (26 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: pyaml, colorlog, scikit-optimize, optuna, fairlearn, scikeras
# Successfully installed colorlog-6.9.0 fairlearn-0.12.0 optuna-4.5.0 pyaml-25.7.0 scikeras-0.13.0 scikit-optimize-0.10.2

# %% [markdown]
# # Import Libraries

# %%
# records and calculations
import pandas as pd
import numpy as np

# visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# core ML
from sklearn.model_selection import train_test_split, StratifiedGroupKFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, precision_recall_curve, confusion_matrix
from sklearn.metrics import classification_report, roc_curve, auc, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.calibration import calibration_curve

# gradient boosting model
import lightgbm as lgb
import xgboost as xgb

# neural network
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier

# optimization
import optuna
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical

# Interpretability
import shap

# Fairness (optional)
from fairlearn.metrics import demographic_parity_difference, equalized_odds_difference

# Persistence
import joblib
import pickle

#  Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load and Prepare Dataset For Modeling

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("/content/data/CleanedLoanData.csv")

# %%
df.head()
# Out:
#    Dependents  LoanAmount  CreditHistory  LoanStatus  TotalIncome  \
# 0           0  146.369492              1           1       5849.0
# 1           1  128.000000              1           0       6091.0
# 2           0   66.000000              1           1       3000.0
# 3           0  120.000000              1           1       4941.0
# 4           0  141.000000              1           1       6000.0
#
#    IncomeLoanRatio  LoanTermYears  Has_CoApplicantIncome  Gender_Male  \
# 0        25.024704           30.0                      0         True
# 1        21.014612           30.0                      1         True
# 2        22.000000           30.0                      0         True
# 3        24.286582           30.0                      1         True
# 4        23.500000           30.0                      0         True
#
#    Married_Yes  Education_Not Graduate  PropertyArea_Semiurban  \
# 0        False                   False                   False
# 1         True                   False                   False
# 2         True                   False                   False
# 3         True                    True                   False
# 4        False                   False                   False
#
#    PropertyArea_Urban  SelfEmployed_Yes
# 0                True             False
# 1               False             False
# 2                True              True
# 3                True             False
# 4                True             False
